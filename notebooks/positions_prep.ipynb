# %% [markdown]
# # Positions Prep
#
# This file contains the process performed on the new `positions.csv` file. The process is the same as the one performed in the `data_cleanup.ipynb` file, but with a few differences.

# %%
import pandas as pd

# read the 'positions.csv' into a DataFrame from the 'data/raw' directory, and make sure that the 'location' and 'aisle',  are 'string's:
positions = pd.read_csv('../data/raw/positions.csv', dtype={'location': 'string', 'aisle': 'string'})
# Treat every column with 'date' in the column name in it as datetime:
date_columns = [name for name in positions.columns if 'date' in name]
positions[date_columns] = pd.to_datetime(positions[date_columns].stack(), dayfirst=True).unstack()  # Stack and unstack are needed because to_datetime works with Series but not with DataFrame.
# lower case all the column names:
positions.columns = map(str.lower, positions.columns)
# uppercase all 'string' values:
positions = positions.applymap(lambda x: x.upper() if isinstance(x, str) else x)
# remove all rows where 'uuid' is null:
positions = positions[positions['uuid'].notnull()]
positions
# Out:
#           uuid  location     last count date  quantity        receive date
# 0      A024200  01010105 2023-04-17 11:59:00      28.0 2023-05-10 12:32:00  \
# 1      A017062  01010109 2023-04-17 12:00:00       2.0 2023-01-23 14:51:00
# 2      A026194  01010109 2023-04-17 12:13:00       6.0 2023-01-08 12:12:00
# 3      A012596  01010113 2023-04-17 12:07:00       6.0 2022-01-20 14:06:00
# 4      A017601  01010113 2023-04-17 12:04:00       3.0 2023-04-13 06:34:00
# ...        ...       ...                 ...       ...                 ...
# 24164  A003724    SORT05                 NaT       2.0 2023-05-30 09:48:00
# 24165  A029187    SORT05                 NaT       1.0 2023-05-25 10:44:00
# 24166  A029804    SORT05                 NaT       1.0 2023-05-30 08:50:00
# 24167  A029876    SORT05                 NaT       1.0 2023-05-24 14:01:00
# 24168  A030397    SORT05                 NaT       1.0 2023-05-25 10:08:00
#
#       last status change date  last movement date putaway zone    fetch zone
# 0         2022-01-20 13:42:00 2022-01-20 13:42:00  OPT-A-01-04  OPT01-04-LOW  \
# 1         2023-01-18 12:03:00 2023-01-19 10:43:00  OPT-A-01-04  OPT01-04-LOW
# 2         2022-01-20 14:15:00 2023-04-17 12:14:00  OPT-A-01-04  OPT01-04-LOW
# 3         2022-01-20 14:06:00 2023-04-17 12:08:00  OPT-A-01-04  OPT01-04-LOW
# 4         2022-01-20 14:02:00 2022-01-20 14:02:00  OPT-A-01-04  OPT01-04-LOW
# ...                       ...                 ...          ...           ...
# 24164     2023-05-30 09:48:00 2023-05-30 09:48:00         SORT          SORT
# 24165     2023-05-25 10:44:00 2023-05-25 10:44:00         SORT          SORT
# 24166     2023-05-30 08:50:00 2023-05-30 08:50:00         SORT          SORT
# 24167     2023-05-24 14:01:00 2023-05-24 14:01:00         SORT          SORT
# 24168     2023-05-25 10:08:00 2023-05-25 10:08:00         SORT          SORT
#
#       warehouse zone aisle
# 0       PASSAGE01-04    01
# 1       PASSAGE01-04    01
# 2       PASSAGE01-04    01
# 3       PASSAGE01-04    01
# 4       PASSAGE01-04    01
# ...              ...   ...
# 24164           SORT  SORT
# 24165           SORT  SORT
# 24166           SORT  SORT
# 24167           SORT  SORT
# 24168           SORT  SORT
#
# [24169 rows x 11 columns]

# %%
# ...        ...       ...                 ...       ...                 ...
# 23958  A005873   FLOOR04                 NaT       1.0 2023-02-08 10:36:00
# 23959  A005529   FLOOR04                 NaT       1.0 2022-11-02 09:43:00
# 23960  A011879   FLOOR04                 NaT       1.0 2023-02-08 10:37:00
# 23961  A011867   FLOOR04 2023-03-30 13:25:00       2.0 2023-02-20 14:41:00
# 23962  A011868   FLOOR04                 NaT       1.0 2022-09-28 13:47:00
#
#       last status change date  last movement date putaway zone    fetch zone
# 0         2022-01-20 13:42:00 2022-01-20 13:42:00  OPT-A-01-04  OPT01-04-LOW  \
# 1         2023-01-18 12:03:00 2023-01-19 10:43:00  OPT-A-01-04  OPT01-04-LOW
# 2         2022-01-20 14:15:00 2023-04-17 12:14:00  OPT-A-01-04  OPT01-04-LOW
# 3         2022-01-20 14:06:00 2023-04-17 12:08:00  OPT-A-01-04  OPT01-04-LOW
# 4         2022-01-20 14:02:00 2022-01-20 14:02:00  OPT-A-01-04  OPT01-04-LOW
# ...                       ...                 ...          ...           ...
# 23958     2023-02-08 10:36:00 2023-02-09 11:15:00  PALLET JACK       DEPOSIT
# 23959     2022-11-02 09:43:00 2022-11-03 13:03:00  PALLET JACK       DEPOSIT
# 23960     2023-02-08 10:37:00 2023-02-09 10:55:00  PALLET JACK       DEPOSIT
# 23961     2023-02-20 14:41:00 2023-02-21 09:50:00  PALLET JACK       DEPOSIT
# 23962     2022-09-28 13:47:00 2022-10-24 13:10:00  PALLET JACK       DEPOSIT
#
#       warehouse zone  aisle
# 0       PASSAGE01-04     01
# 1       PASSAGE01-04     01
# 2       PASSAGE01-04     01
# 3       PASSAGE01-04     01
# 4       PASSAGE01-04     01
# ...              ...    ...
# 23958    PALLET JACK  FLOOR
# 23959    PALLET JACK  FLOOR
# 23960    PALLET JACK  FLOOR
# 23961    PALLET JACK  FLOOR
# 23962    PALLET JACK  FLOOR
#
# [23819 rows x 11 columns]

# %%
# get the the 'location type' column from the 'old_positions_data.xlsc' file:
location_types = pd.read_excel('../data/raw/old_positions_data.xlsx', sheet_name="position", usecols=['location', 'location type'])
# uppercase all 'string' values:
location_types = location_types.applymap(lambda x: x.upper() if isinstance(x, str) else x)
location_types
# Out:
#        location location type
# 0      09040304         FLOOR
# 1      09040102         FLOOR
# 2      09040204         FLOOR
# 3      09060201         FLOOR
# 4      09080104         FLOOR
# ...         ...           ...
# 25842  02090719  ORDER PICKER
# 25843  04110104         FLOOR
# 25844  40260901    REACH FORK
# 25845  40260901    REACH FORK
# 25846  06010404         FLOOR
#
# [25847 rows x 2 columns]

# %%
# check how many values are missing in the 'location type' column:
location_types['location type'].isnull().sum()
# Out:
# 0

# %%
# merge both DataFrames on the 'location' column:
positions = positions.merge(location_types, on='location', how='left')
positions
# Out:
#            uuid  location     last count date  quantity        receive date
# 0       A024200  01010105 2023-04-17 11:59:00      28.0 2023-05-10 12:32:00  \
# 1       A024200  01010105 2023-04-17 11:59:00      28.0 2023-05-10 12:32:00
# 2       A017062  01010109 2023-04-17 12:00:00       2.0 2023-01-23 14:51:00
# 3       A026194  01010109 2023-04-17 12:13:00       6.0 2023-01-08 12:12:00
2022-09-28 13:47:00 2022-10-24 13:10:00  PALLET JACK       DEPOSIT
#
#       warehouse zone  aisle location type
# 0       PASSAGE01-04     01         FLOOR
# 1       PASSAGE01-04     01         FLOOR
# 2       PASSAGE01-04     01         FLOOR
# 3       PASSAGE01-04     01         FLOOR
# 4       PASSAGE01-04     01         FLOOR
# ...              ...    ...           ...
# 23812    PALLET JACK  FLOOR   PALLET JACK
# 23813    PALLET JACK  FLOOR   PALLET JACK
# 23814    PALLET JACK  FLOOR   PALLET JACK
# 23815    PALLET JACK  FLOOR   PALLET JACK
# 23816    PALLET JACK  FLOOR   PALLET JACK
#
# [23817 rows x 12 columns]

# %%
# how many missing values are in each column:
positions.isnull().sum()
# Out:
# uuid                          0
# location                      0
# last count date            2363
# quantity                      0
# receive date                  0
# last status change date       0
# last movement date            0
# putaway zone                  0
# fetch zone                    0
# warehouse zone                0
# aisle                         0
# location type               763
# dtype: int64

# %%
# show which rows have missing values in the 'location type' column:
positions[positions['location type'].isnull()]
# Out:
#           uuid  location     last count date  quantity        receive date
# 97     A016421  01010719                 NaT       2.0 2023-04-09 09:18:00  \
# 426    A004630  01020501                 NaT       2.0 2023-04-18 11:19:00
# 432    A022504  01020525 2023-04-18 11:49:00       1.0 2023-04-18 11:49:00
# 435    A022424  01020605 2023-04-18 13:01:00       5.0 2023-05-17 09:58:00
# 439    A005189  01020621                 NaT       8.0 2023-05-01 16:01:00
# ...        ...       ...                 ...       ...                 ...
# 23505  A005110  60130303                 NaT       2.0 2023-04-18 10:34:00
# 23579  A005514  60200303                 NaT       1.0 2023-04-18 09:42:00
# 23580  A010697  60210102                 NaT       7.0 2022-11-08 15:01:00
# 23597  A010729  60220303                 NaT       1.0 2023-04-18 10:07:00
# 23598  A008540  60220303                 NaT       2.0 2023-04-19 09:41:00
#
#       last status change date  last movement date putaway zone    fetch zone
# 97        2023-04-09 09:18:00 2023-04-16 10:54:00  OPT-B-01-04         OPT01  \
# 426       2023-04-18 11:19:00 2023-04-20 11:16:00  OPT-A-01-04  OPT01-04-LOW
# 432       2023-04-18 11:49:00 2023-04-18 11:49:00  OPT-A-01-04  OPT01-04-LOW
# 435       2023-04-09 09:17:00 2023-04-16 10:55:00  OPT-A-01-04  OPT01-04-LOW
# 439       2023-05-01 16:01:00 2023-05-03 11:49:00  OPT-A-01-04  OPT01-04-LOW
# ...                       ...                 ...          ...           ...
# 23505     2023-04-19 12:29:00 2023-04-19 12:29:00     PALLET-B        PALLET
# 23579     2023-04-18 09:42:00 2023-04-19 14:29:00     PALLET-B        PALLET
# 23580     2022-11-08 15:01:00 2023-04-27 14:24:00  PALLET JACK   PALLET JACK
# 23597     2023-04-18 10:07:00 2023-04-19 12:12:00     PALLET-B        PALLET
# 23598     2023-04-19 09:41:00 2023-04-19 12:12:00     PALLET-B        PALLET
#
#       warehouse zone aisle location type
# 97      PASSAGE01-04    01           NaN
# 426     PASSAGE01-04    01           NaN
# 432     PASSAGE01-04    01           NaN
# 435     PASSAGE01-04    01           NaN
# 439     PASSAGE01-04    01           NaN
# ...              ...   ...           ...
# 23505      PASSAGE60    60           NaN
# 23579      RL-STORGE    60           NaN
# 23580      PASSAGE60    60           NaN
# 23597      RL-STORGE    60           NaN
# 23598      RL-STORGE    60           NaN
#
# [763 rows x 12 columns]

# %%
# fill all NaN values in the 'location type' column with 'unknown':
positions['location type'] = positions['location type'].fillna('unknown')

# show all different groupings of 'putaway zone', 'fetch zone' and 'location type', save as a variable:
zone_groupings = positions.groupby(['putaway zone', 'fetch zone', 'location type']).size().reset_index().rename(columns={0:'count'})
zone_groupings
# Out:
#    putaway zone   fetch zone location type  count
# 0        BITNOT       BITNOT         FLOOR     53
# 1        BITNOT    OPT07-LOW         FLOOR      6
# 2        BITNOT        OPT09  ORDER PICKER      2
# 3   CANTI-HEAVY        OPT05  ORDER PICKER    136
# 4   CANTI-HEAVY    OPT06-LOW         FLOOR     46
# ..          ...          ...           ...    ...
# 95     PALLET-A  PALLET JACK       unknown      6
# 96     PALLET-B       PALLET    REACH FORK    362
# 97     PALLET-B       PALLET       unknown     19
# 98     PALLET-C       PALLET    REACH FORK    829
# 99     PALLET-C       PALLET       unknown      8
#
# [100 rows x 4 columns]

# %%
# filter out from zone_groupings all 'putaway zone's which don't have at least one row with 'location type' == 'unknown':
zones_with_unkown_values = zone_groupings[zone_groupings['location type'] == 'unknown']['putaway zone'].unique()
# from the zone_groupings DataFrame, leave only the rows where the 'putaway zone' is in the zones_with_unkown_values list:
zone_groupings = zone_groupings[zone_groupings['putaway zone'].isin(zones_with_unkown_values)]
# sort by 'putaway zone' and 'fetch zone':
zone_groupings = zone_groupings.sort_values(by=['putaway zone', 'fetch zone'])
zone_groupings
# Out:
#    putaway zone   fetch zone location type  count
# 5   CANTI-LIGHT        OPT05  ORDER PICKER     59
# 6   CANTI-LIGHT        OPT05       unknown      1
# 7   CANTI-LIGHT    OPT06-LOW         FLOOR     36
# 8   CANTI-LIGHT    OPT06-LOW       unknown      1
# 10         HIVE        OPT07         FLOOR      1
# ..          ...          ...           ...    ...
# 95     PALLET-A  PALLET JACK       unknown      6
# 96     PALLET-B       PALLET    REACH FORK    362
# 97     PALLET-B       PALLET       unknown     19
# 98     PALLET-C       PALLET    REACH FORK    829
# 99     PALLET-C       PALLET       unknown      8
#
# [93 rows x 4 columns]

# %%
# in zone_groupings, for every group of 'putaway zone' and 'fetch zone', apply the following function:
def fill_unknowns(group):
    # if there are two rows in the group, and one of them has 'location type' == 'unknown':
    if len(group) == 2 and 'unknown' in group['location type'].values:
        # remove the row with 'location type' == 'unknown':
        group = group[group['location type'] != 'unknown']
    # return the group:
    return group

# apply the fill_unknowns function to the zone_groupings DataFrame:
zone_groupings = zone_groupings.groupby(['putaway zone', 'fetch zone']).apply(fill_unknowns)[['location type']]
zone_groupings.head()
# Out:
#                            location type
# putaway zone fetch zone
# CANTI-LIGHT  OPT05      5   ORDER PICKER
#              OPT06-LOW  7          FLOOR
# HIVE         OPT07      10         FLOOR
#              OPT07-LOW  11         FLOOR
#              OPT09-LOW  13         FLOOR

# %%
# take zone_groupings and take the index columns and make them into columns:
zone_groupings = zone_groupings.reset_index()
zone_groupings.head()
# Out:
#   putaway zone fetch zone  level_2 location type
# 0  CANTI-LIGHT      OPT05        5  ORDER PICKER
# 1  CANTI-LIGHT  OPT06-LOW        7         FLOOR
# 2         HIVE      OPT07       10         FLOOR
# 3         HIVE  OPT07-LOW       11         FLOOR
# 4         HIVE  OPT09-LOW       13         FLOOR

# %%
# drop the 'level_2' column:
zone_groupings = zone_groupings.drop(columns=['level_2'])
zone_groupings
# Out:
#    putaway zone    fetch zone location type
# 0   CANTI-LIGHT         OPT05  ORDER PICKER
# 1   CANTI-LIGHT     OPT06-LOW         FLOOR
# 2          HIVE         OPT07         FLOOR
# 3          HIVE     OPT07-LOW         FLOOR
# 4          HIVE     OPT09-LOW         FLOOR
# 5     MERAKEZET     OPT06-LOW         FLOOR
# 6   OPT-A-01-04  OPT01-04-LOW         FLOOR
# 7   OPT-A-05-07         OPT05  ORDER PICKER
# 8   OPT-A-05-07         OPT06  ORDER PICKER
# 9   OPT-A-05-07     OPT06-LOW         FLOOR
# 10  OPT-A-05-07     OPT06-LOW  ORDER PICKER
# 11  OPT-A-05-07     OPT06-LOW       unknown
# 12  OPT-A-07-11         OPT07         FLOOR
# 13  OPT-A-07-11         OPT07  ORDER PICKER
# 14  OPT-A-07-11         OPT07       unknown
# 15  OPT-A-07-11     OPT07-LOW         FLOOR
# 16  OPT-A-07-11         OPT09  ORDER PICKER
# 17  OPT-A-07-11     OPT09-LOW         FLOOR
# 18  OPT-A-07-11         OPT10  ORDER PICKER
# 19  OPT-A-07-11         OPT11  ORDER PICKER
# 20  OPT-A-07-11     OPT11-LOW         FLOOR
# 21     OPT-A-08     OPT07-LOW         FLOOR
# 22     OPT-A-08         OPT08  ORDER PICKER
# 23  OPT-B-01-04         OPT01  ORDER PICKER
# 24  OPT-B-01-04         OPT02  ORDER PICKER
# 25  OPT-B-01-04         OPT03  ORDER PICKER
# 26  OPT-B-01-04         OPT04  ORDER PICKER
# 27  OPT-B-05-07         OPT05  ORDER PICKER
# 28  OPT-B-05-07         OPT06  ORDER PICKER
# 29  OPT-B-07-11         OPT07  ORDER PICKER
# 30  OPT-B-07-11         OPT09  ORDER PICKER
# 31  OPT-B-07-11         OPT10  ORDER PICKER
# 32  OPT-B-07-11         OPT11  ORDER PICKER
# 33     OPT-B-08         OPT08  ORDER PICKER
# 34  OPT-C-01-04         OPT01  ORDER PICKER
# 35  OPT-C-01-04         OPT02  ORDER PICKER
# 36  OPT-C-01-04         OPT03  ORDER PICKER
# 37  OPT-C-01-04         OPT04  ORDER PICKER
# 38  OPT-C-05-07         OPT05  ORDER PICKER
# 39  OPT-C-05-07         OPT06  ORDER PICKER
# 40  OPT-C-07-11         OPT07  ORDER PICKER
# 41  OPT-C-07-11         OPT09  ORDER PICKER
# 42  OPT-C-07-11         OPT10  ORDER PICKER
# 43  OPT-C-07-11         OPT11  ORDER PICKER
# 44     OPT-C-08         OPT08  ORDER PICKER
# 45   OPT-MDK-14         OPT03  ORDER PICKER
# 46   OPT-MDK-14         OPT04  ORDER PICKER
# 47  PALLET JACK       DEPOSIT   PALLET JACK
# 48  PALLET JACK   PALLET JACK         FLOOR
# 49     PALLET-A        PALLET    REACH FORK
# 50     PALLET-A   PALLET JACK         FLOOR
# 51     PALLET-B        PALLET    REACH FORK
# 52     PALLET-C        PALLET    REACH FORK

# %%
# from zone_groupings, take only the rows where 'location type' == 'unknown':
unknown_locations = zone_groupings[zone_groupings['location type'] == 'unknown'][['putaway zone', 'fetch zone']]
unknown_locations
# Out:
#    putaway zone fetch zone
# 11  OPT-A-05-07  OPT06-LOW
# 14  OPT-A-07-11      OPT07

# %%
# take the values from both columns of unknown_locations and unite them into one string:
unknown_locations['zones'] = unknown_locations.apply(lambda x: '_'.join(x), axis=1)
unknown_locations
# Out:
#    putaway zone fetch zone                  zones
# 11  OPT-A-05-07  OPT06-LOW  OPT-A-05-07_OPT06-LOW
# 14  OPT-A-07-11      OPT07      OPT-A-07-11_OPT07

# %%
zone_groupings['zones'] = zone_groupings['putaway zone'] + '_' + zone_groupings['fetch zone']
# from zone_groupings, filter out rows which have 'zones' values which can be found in unknown_locations:
zone_groupings = zone_groupings[~zone_groupings['zones'].isin(unknown_locations['zones'])]
zone_groupings
# Out:
#    putaway zone    fetch zone location type                     zones
# 0   CANTI-LIGHT         OPT05  ORDER PICKER         CANTI-LIGHT_OPT05
# 1   CANTI-LIGHT     OPT06-LOW         FLOOR     CANTI-LIGHT_OPT06-LOW
# 2          HIVE         OPT07         FLOOR                HIVE_OPT07
# 3          HIVE     OPT07-LOW         FLOOR            HIVE_OPT07-LOW
# 4          HIVE     OPT09-LOW         FLOOR            HIVE_OPT09-LOW
# 5     MERAKEZET     OPT06-LOW         FLOOR       MERAKEZET_OPT06-LOW
# 6   OPT-A-01-04  OPT01-04-LOW         FLOOR  OPT-A-01-04_OPT01-04-LOW
# 7   OPT-A-05-07         OPT05  ORDER PICKER         OPT-A-05-07_OPT05
# 8   OPT-A-05-07         OPT06  ORDER PICKER         OPT-A-05-07_OPT06
# 15  OPT-A-07-11     OPT07-LOW         FLOOR     OPT-A-07-11_OPT07-LOW
# 16  OPT-A-07-11         OPT09  ORDER PICKER         OPT-A-07-11_OPT09
# 17  OPT-A-07-11     OPT09-LOW         FLOOR     OPT-A-07-11_OPT09-LOW
# 18  OPT-A-07-11         OPT10  ORDER PICKER         OPT-A-07-11_OPT10
# 19  OPT-A-07-11         OPT11  ORDER PICKER         OPT-A-07-11_OPT11
# 20  OPT-A-07-11     OPT11-LOW         FLOOR     OPT-A-07-11_OPT11-LOW
# 21     OPT-A-08     OPT07-LOW         FLOOR        OPT-A-08_OPT07-LOW
# 22     OPT-A-08         OPT08  ORDER PICKER            OPT-A-08_OPT08
# 23  OPT-B-01-04         OPT01  ORDER PICKER         OPT-B-01-04_OPT01
# 24  OPT-B-01-04         OPT02  ORDER PICKER         OPT-B-01-04_OPT02
# 25  OPT-B-01-04         OPT03  ORDER PICKER         OPT-B-01-04_OPT03
# 26  OPT-B-01-04         OPT04  ORDER PICKER         OPT-B-01-04_OPT04
# 27  OPT-B-05-07         OPT05  ORDER PICKER         OPT-B-05-07_OPT05
# 28  OPT-B-05-07         OPT06  ORDER PICKER         OPT-B-05-07_OPT06
# 29  OPT-B-07-11         OPT07  ORDER PICKER         OPT-B-07-11_OPT07
# 30  OPT-B-07-11         OPT09  ORDER PICKER         OPT-B-07-11_OPT09
# 31  OPT-B-07-11         OPT10  ORDER PICKER         OPT-B-07-11_OPT10
# 32  OPT-B-07-11         OPT11  ORDER PICKER         OPT-B-07-11_OPT11
# 33     OPT-B-08         OPT08  ORDER PICKER            OPT-B-08_OPT08
# 34  OPT-C-01-04         OPT01  ORDER PICKER         OPT-C-01-04_OPT01
# 35  OPT-C-01-04         OPT02  ORDER PICKER         OPT-C-01-04_OPT02
# 36  OPT-C-01-04         OPT03  ORDER PICKER         OPT-C-01-04_OPT03
# 37  OPT-C-01-04         OPT04  ORDER PICKER         OPT-C-01-04_OPT04
# 38  OPT-C-05-07         OPT05  ORDER PICKER         OPT-C-05-07_OPT05
# 39  OPT-C-05-07         OPT06  ORDER PICKER         OPT-C-05-07_OPT06
# 40  OPT-C-07-11         OPT07  ORDER PICKER         OPT-C-07-11_OPT07
# 41  OPT-C-07-11         OPT09  ORDER PICKER         OPT-C-07-11_OPT09
# 42  OPT-C-07-11         OPT10  ORDER PICKER         OPT-C-07-11_OPT10
# 43  OPT-C-07-11         OPT11  ORDER PICKER         OPT-C-07-11_OPT11
# 44     OPT-C-08         OPT08  ORDER PICKER            OPT-C-08_OPT08
# 45   OPT-MDK-14         OPT03  ORDER PICKER          OPT-MDK-14_OPT03
# 46   OPT-MDK-14         OPT04  ORDER PICKER          OPT-MDK-14_OPT04
# 47  PALLET JACK       DEPOSIT   PALLET JACK       PALLET JACK_DEPOSIT
# 48  PALLET JACK   PALLET JACK         FLOOR   PALLET JACK_PALLET JACK
# 49     PALLET-A        PALLET    REACH FORK           PALLET-A_PALLET
# 50     PALLET-A   PALLET JACK         FLOOR      PALLET-A_PALLET JACK
# 51     PALLET-B        PALLET    REACH FORK           PALLET-B_PALLET
# 52     PALLET-C        PALLET    REACH FORK           PALLET-C_PALLET

# %%
# in positions DataFrame, for every row, if the 'location type' is 'unknown', replace it with NaN:
import numpy as np
positions['location type'] = positions['location type'].replace('unknown', np.nan)

# %%
# merge the zone_groupings DataFrame with the positions DataFrame on the 'putaway zone' and 'fetch zone' columns:
# where location type is NaN, replace it with the value from the zone_groupings DataFrame:
positions = positions.merge(zone_groupings.drop(labels='zones', axis=1), on=['putaway zone', 'fetch zone'], how='left')
positions['location type_x'] = positions['location type_x'].fillna(positions['location type_y'])
# drop the 'location type_y' column:
positions = positions.drop(columns=['location type_y'])
# rename the 'location type_x' column to 'location type':
positions = positions.rename(columns={'location type_x': 'location type'})
positions
# Out:
#           uuid  location     last count date  quantity        receive date
# 0      A024200  01010105 2023-04-17 11:59:00      28.0 2023-05-10 12:32:00  \
# 1      A017062  01010109 2023-04-17 12:00:00       2.0 2023-01-23 14:51:00
# 2      A026194  01010109 2023-04-17 12:13:00       6.0 2023-01-08 12:12:00
# 3      A012596  01010113 2023-04-17 12:07:00       6.0 2022-01-20 14:06:00
# 4      A017601  01010113 2023-04-17 12:04:00       3.0 2023-04-13 06:34:00
# ...        ...       ...                 ...       ...                 ...
# 23812  A005873   FLOOR04                 NaT       1.0 2023-02-08 10:36:00
# 20146  A009706  07260504 2023-04-30 07:34:00       5.0 2023-05-01 15:41:00
# 20246  A009618  07280302                 NaT       3.0 2023-05-01 15:32:00
# 20254  A006800  07280701 2023-05-02 06:36:00       2.0 2023-04-02 10:36:00
#
#       last status change date  last movement date putaway zone fetch zone
# 16181     2023-01-31 09:06:00 2023-04-16 13:08:00  OPT-A-05-07  OPT06-LOW  \
# 16689     2022-10-12 09:51:00 2023-04-04 10:41:00  OPT-A-05-07  OPT06-LOW
# 18956     2023-04-24 06:30:00 2023-04-24 06:30:00  OPT-A-07-11      OPT07
# 18957     2023-04-24 06:28:00 2023-04-24 06:28:00  OPT-A-07-11      OPT07
# 18958     2023-04-24 06:32:00 2023-04-24 06:32:00  OPT-A-07-11      OPT07
# 19042     2023-04-24 07:06:00 2023-04-24 07:06:00  OPT-A-07-11      OPT07
# 19220     2023-05-16 14:56:00 2023-05-17 06:33:00  OPT-A-07-11      OPT07
# 19221     2022-08-23 14:45:00 2023-04-04 14:26:00  OPT-A-07-11      OPT07
# 19229     2023-04-27 06:18:00 2023-04-27 06:18:00  OPT-A-07-11      OPT07
# 19563     2022-12-22 10:37:00 2023-04-04 10:31:00  OPT-A-07-11      OPT07
# 19565     2023-05-16 13:29:00 2023-05-16 15:40:00  OPT-A-07-11      OPT07
# 19566     2023-01-01 06:24:00 2023-04-04 10:30:00  OPT-A-07-11      OPT07
# 19623     2023-05-11 11:11:00 2023-05-12 06:22:00  OPT-A-07-11      OPT07
# 19934     2023-05-18 11:58:00 2023-05-22 06:58:00  OPT-A-07-11      OPT07
# 20146     2023-04-10 08:27:00 2023-04-11 06:08:00  OPT-A-07-11      OPT07
# 20246     2023-05-01 15:32:00 2023-05-02 10:08:00  OPT-A-07-11      OPT07
# 20254     2023-04-02 10:36:00 2023-04-11 11:07:00  OPT-A-07-11      OPT07
#
#       warehouse zone aisle location type
# 16181      PASSAGE05    05           NaN
# 16689      PASSAGE05    05           NaN
# 18956      PASSAGE07    07           NaN
# 18957      PASSAGE07    07           NaN
# 18958      PASSAGE07    07           NaN
# 19042      PASSAGE07    07           NaN
# 19220      PASSAGE07    07           NaN
# 19221      PASSAGE07    07           NaN
# 19229      PASSAGE07    07           NaN
# 19563      PASSAGE07    07           NaN
# 19565      PASSAGE07    07           NaN
# 19566      PASSAGE07    07           NaN
# 19623      PASSAGE07    07           NaN
# 19934      PASSAGE07    07           NaN
# 20146      PASSAGE07    07           NaN
# 20246      PASSAGE07    07           NaN
# 20254      PASSAGE07    07           NaN

# %%
# for every row in positions, if the 'location type' is NaN, check the previous and next rows:
# if the 'location type' in the previous row is the same as in the next row, replace the NaN with the value from the previous row:
for index, row in positions.iterrows():
    if pd.isnull(row['location type']):
        if positions.iloc[index-1]['location type'] == positions.iloc[index+1]['location type']:
            positions.at[index, 'location type'] = positions.iloc[index-1]['location type']
positions
# Out:
#           uuid  location     last count date  quantity        receive date
# 0      A024200  01010105 2023-04-17 11:59:00      28.0 2023-05-10 12:32:00  \
# 1      A017062  01010109 2023-04-17 12:00:00       2.0 2023-01-23 14:51:00
# 18956     2023-04-24 06:30:00 2023-04-24 06:30:00  OPT-A-07-11      OPT07  \
# 18957     2023-04-24 06:28:00 2023-04-24 06:28:00  OPT-A-07-11      OPT07
# 18958     2023-04-24 06:32:00 2023-04-24 06:32:00  OPT-A-07-11      OPT07
# 19220     2023-05-16 14:56:00 2023-05-17 06:33:00  OPT-A-07-11      OPT07
# 19221     2022-08-23 14:45:00 2023-04-04 14:26:00  OPT-A-07-11      OPT07
# 19563     2022-12-22 10:37:00 2023-04-04 10:31:00  OPT-A-07-11      OPT07
# 19565     2023-05-16 13:29:00 2023-05-16 15:40:00  OPT-A-07-11      OPT07
# 19566     2023-01-01 06:24:00 2023-04-04 10:30:00  OPT-A-07-11      OPT07
#
#       warehouse zone aisle location type
# 18956      PASSAGE07    07           NaN
# 18957      PASSAGE07    07           NaN
# 18958      PASSAGE07    07           NaN
# 19220      PASSAGE07    07           NaN
# 19221      PASSAGE07    07           NaN
# 19563      PASSAGE07    07           NaN
# 19565      PASSAGE07    07           NaN
# 19566      PASSAGE07    07           NaN

# %%
# for every row in positions, if the 'location type' is NaN, print the row, and print the 'location type' values of the previous and next rows:
for index, row in positions.iterrows():
    if pd.isnull(row['location type']):
        print(index-1, positions.iloc[index-1]['location'], positions.iloc[index-1]['location type'])
        print(index, row['location'])
        print(index+1, positions.iloc[index+1]['location'], positions.iloc[index+1]['location type'])
        print('------------------')
# Out:
# 18955 07020702 ORDER PICKER
# 18956 07020703
# 18957 07020703 nan
# ------------------
# 18956 07020703 nan
# 18957 07020703
# 18958 07020703 nan
# ------------------
# 18957 07020703 nan
# 18958 07020703
# 18959 07020704 ORDER PICKER
# ------------------
# 19219 07080301 ORDER PICKER
# 19220 07080302
# 19221 07080303 nan
# ------------------
# 19220 07080302 nan
# 19221 07080303
# 19222 07080304 ORDER PICKER
# ------------------
# 19562 07150404 FLOOR
# 19563 07150501
# 19564 07150502 ORDER PICKER
# ------------------
# 19564 07150502 ORDER PICKER
# 19565 07150503
# 19566 07150503 nan
# ------------------
# 19565 07150503 nan
# 19566 07150503
# 19567 07150504 ORDER PICKER
# ------------------

# %% [markdown]
# We can see the all of the rows which have still have a missing value in the `position` column, are mostly consecutive rows.
#
# We can see that all appearances of this show a phenomenon of having the same `loclevel` values (except for `83505`, which has a previous row which isn't on the same shelf). As such, we can decide that the `position` column can be filled in by using the `bfill()` method.

# %%
# show which rows have missing values in the 'location type' column:
positions[positions['location type'].isnull()]
# Out:
#           uuid  location     last count date  quantity        receive date
# 18956  A009592  07020703 2023-04-24 06:30:00       1.0 2023-04-24 06:30:00  \
# 18957  A009593  07020703 2023-04-24 06:28:00       1.0 2023-04-24 06:28:00
# 18958  A005096  07020703 2023-04-24 06:32:00       4.0 2023-04-24 06:32:00
# 19220  A028205  07080302                 NaT       4.0 2023-05-23 07:36:00
# 19221  A005686  07080303 2023-04-27 06:25:00       3.0 2023-01-24 11:05:00
# 19563  A028374  07150501 2023-05-08 06:29:00       3.0 2023-03-29 09:53:00
# 19565  A014089  07150503                 NaT       2.0 2023-05-16 13:29:00
# 19566  A029461  07150503 2023-05-08 06:30:00       4.0 2023-02-16 06:25:00
#
#       last status change date  last movement date putaway zone fetch zone
# 18956     2023-04-24 06:30:00 2023-04-24 06:30:00  OPT-A-07-11      OPT07  \
# 18957     2023-04-24 06:28:00 2023-04-24 06:28:00  OPT-A-07-11      OPT07
# 18958     2023-04-24 06:32:00 2023-04-24 06:32:00  OPT-A-07-11      OPT07
# 19220     2023-05-16 14:56:00 2023-05-17 06:33:00  OPT-A-07-11      OPT07
# 19221     2022-08-23 14:45:00 2023-04-04 14:26:00  OPT-A-07-11      OPT07
# 19563     2022-12-22 10:37:00 2023-04-04 10:31:00  OPT-A-07-11      OPT07
# 19565     2023-05-16 13:29:00 2023-05-16 15:40:00  OPT-A-07-11      OPT07
# 19566     2023-01-01 06:24:00 2023-04-04 10:30:00  OPT-A-07-11      OPT07
#
#       warehouse zone aisle location type
# 18956      PASSAGE07    07           NaN
# 18957      PASSAGE07    07           NaN
# 18958      PASSAGE07    07           NaN
# 19220      PASSAGE07    07           NaN
# 19221      PASSAGE07    07           NaN
# 19563      PASSAGE07    07           NaN
# 19565      PASSAGE07    07           NaN
# 19566      PASSAGE07    07           NaN

# %%
# for every row with 'location type' == 'unknown', bfill it:
positions['location type'] = positions['location type'].replace('unknown', np.nan).bfill()

# %%
# show all rows in which 'quantity' isn't a full number:
positions[positions['quantity'] % 1 != 0]
# Out:
#           uuid  location     last count date  quantity        receive date
# 13257  A000116  04051102 2023-05-02 07:19:00      37.5 2022-08-28 15:05:00  \
# 15387  A000057  05010901 2022-11-07 11:13:00       7.7 2023-02-19 10:45:00
# 15490  A000023  05030202                 NaT       3.1 2023-02-27 10:32:00
# 15515  A000036  05030601 2022-11-07 13:11:00       3.6 2023-02-01 09:34:00
# 15846  A000056  05073101 2023-05-09 07:48:00       2.6 2023-02-19 10:43:00
#
#       last status change date  last movement date putaway zone fetch zone
# 13257     2022-08-28 15:05:00 2022-08-28 15:09:00  OPT-B-01-04      OPT04  \
# 15387     2022-11-07 11:13:00 2022-11-07 11:13:00  CANTI-LIGHT      OPT05
# 15490     2023-02-27 10:32:00 2023-03-07 09:08:00  CANTI-HEAVY  OPT06-LOW
# 15515     2022-11-07 13:11:00 2022-11-07 13:11:00  CANTI-HEAVY      OPT05
# 15846     2023-02-19 10:43:00 2023-02-21 13:07:00  OPT-C-05-07      OPT05
#
#       warehouse zone aisle location type
# 13257   PASSAGE01-04    04  ORDER PICKER
# 15387      PASSAGE05    05  ORDER PICKER
# 15490      PASSAGE05    05         FLOOR
# 15515      PASSAGE05    05  ORDER PICKER
# 15846      PASSAGE05    05  ORDER PICKER

# %%
# round up all values in the 'quantity' column:
positions['quantity'] = positions['quantity'].apply(np.ceil)
positions[positions['quantity'] % 1 != 0]
# Out:
# Empty DataFrame
# Columns: [uuid, location, last count date, quantity, receive date, last status change date, last movement date, putaway zone, fetch zone, warehouse zone, aisle, location type]
# Index: []

# %%
# turn the 'quantity' column into integers:
positions['quantity'] = positions['quantity'].astype(int)

# %%
positions = positions.rename(columns={'location type': 
'fetch_tool'})
# replace whitespaces with underscores in all column names:
positions.columns = positions.columns.str.replace(' ', '_')
positions['location'] = np.where(
    positions['location'].str.contains('FLOOR'), positions['location'], positions['location'].str[:-2])
# uppercase all values within the table:
positions = positions.apply(lambda x: x.str.upper() if x.dtype == "string" else x)
# within the table, replace all whitespaces with underscores:
positions = positions.apply(lambda x: x.str.replace(' ', '_') if x.dtype == "string" else x)
positions
# Out:
#           uuid location     last_count_date  quantity        receive_date
# 0      A024200   010101 2023-04-17 11:59:00        28 2023-05-10 12:32:00  \
# 1      A017062   010101 2023-04-17 12:00:00         2 2023-01-23 14:51:00
# 2      A026194   010101 2023-04-17 12:13:00         6 2023-01-08 12:12:00
# 3      A012596   010101 2023-04-17 12:07:00         6 2022-01-20 14:06:00
# 4      A017601   010101 2023-04-17 12:04:00         3 2023-04-13 06:34:00
# ...        ...      ...                 ...       ...                 ...
# 23812  A005873  FLOOR04                 NaT         1 2023-02-08 10:36:00
# 23813  A005529  FLOOR04                 NaT         1 2022-11-02 09:43:00
# 23814  A011879  FLOOR04                 NaT         1 2023-02-08 10:37:00
# 23815  A011867  FLOOR04 2023-03-30 13:25:00         2 2023-02-20 14:41:00
# 23816  A011868  FLOOR04                 NaT         1 2022-09-28 13:47:00
#
#       last_status_change_date  last_movement_date putaway_zone    fetch_zone
# 0         2022-01-20 13:42:00 2022-01-20 13:42:00  OPT-A-01-04  OPT01-04-LOW  \
# 1         2023-01-18 12:03:00 2023-01-19 10:43:00  OPT-A-01-04  OPT01-04-LOW
# 2         2022-01-20 14:15:00 2023-04-17 12:14:00  OPT-A-01-04  OPT01-04-LOW
# 3         2022-01-20 14:06:00 2023-04-17 12:08:00  OPT-A-01-04  OPT01-04-LOW
# 4         2022-01-20 14:02:00 2022-01-20 14:02:00  OPT-A-01-04  OPT01-04-LOW
# ...                       ...                 ...          ...           ...
# 23812     2023-02-08 10:36:00 2023-02-09 11:15:00  PALLET JACK       DEPOSIT
# 23813     2022-11-02 09:43:00 2022-11-03 13:03:00  PALLET JACK       DEPOSIT
# 23814     2023-02-08 10:37:00 2023-02-09 10:55:00  PALLET JACK       DEPOSIT
# 23815     2023-02-20 14:41:00 2023-02-21 09:50:00  PALLET JACK       DEPOSIT
# 23816     2022-09-28 13:47:00 2022-10-24 13:10:00  PALLET JACK       DEPOSIT
#
#       warehouse_zone  aisle   fetch_tool
# 0       PASSAGE01-04     01        FLOOR
# 1       PASSAGE01-04     01        FLOOR
# 2       PASSAGE01-04     01        FLOOR
# 3       PASSAGE01-04     01        FLOOR
# 4       PASSAGE01-04     01        FLOOR
# ...              ...    ...          ...
# 23812    PALLET JACK  FLOOR  PALLET JACK
# 23813    PALLET JACK  FLOOR  PALLET JACK
# 23814    PALLET JACK  FLOOR  PALLET JACK
# 23815    PALLET JACK  FLOOR  PALLET JACK
# 23816    PALLET JACK  FLOOR  PALLET JACK
#
# [23817 rows x 12 columns]

# %% [markdown]
# Export the positions.csv for inner data usage:

# %%
# export as a csv file:
import csv
positions.to_csv('../data/processed/positions.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)
